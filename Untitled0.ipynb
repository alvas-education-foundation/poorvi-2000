# %% [markdown]
# <a href="https://colab.research.google.com/github/alvas-education-foundation/poorvi-2000/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle

n=int(input("Enter number:"));
for i in range(n+1):
    c=i
    for j in range(1,i+1):
        print(c, end=" ")
        c=c+1
    print('')
Enter number:4

1 
2 3 
3 4 5 
4 5 6 7 
In [0]:

In [2]:
rows = 4
for i in range(0, rows):
    for j in range(0, i + 1):
        print("*", end=' ')

    print("\r")
* 
* * 
* * * 
* * * * 
In [0]:

In [3]:
n=int(input("Enter number:"));
for i in range(n+1):
    c=n-i+1
    for j in range(n,n-i,-1):
        print(c, end=" ")
        c=c+1
    print('')
Enter number:5

5 
4 5 
3 4 5 
2 3 4 5 
1 2 3 4 5 
In [0]:


Open In Colab
In [0]:

Write a program to print the triangle

In [0]:

In [1]:
n=int(input("Enter number:"));
for i in range(n+1):
    c=i
    for j in range(1,i+1):
        print(c, end=" ")
        c=c+1
    print('')
Enter number:4

1 
2 3 
3 4 5 
4 5 6 7 
In [0]:

In [2]:
rows = 4
for i in range(0, rows):
    for j in range(0, i + 1):
        print("*", end=' ')

    print("\r")
* 
* * 
* * * 
* * * * 
In [0]:

In [3]:
n=int(input("Enter number:"));
for i in range(n+1):
    c=n-i+1
    for j in range(n,n-i,-1):
        print(c, end=" ")
        c=c+1
    print('')
Enter number:5

5 
4 5 
3 4 5 
2 3 4 5 
1 2 3 4 5 
In [0]:

In [4]:
rows = 5
for i in range(0, rows + 1):
    for j in range(rows - i, 0, -1):
        print(j, end=' ')
    print()
5 4 3 2 1 
4 3 2 1 
3 2 1 
2 1 
1 

In [5]:
n=int(input("Enter number:"));
for i in range(n):
    for j in range(i+1,n+1,1):
        print(j, end=" ")
    print('')
for i in range(2,n+1):
    c=n-i+1
    for j in range(n,n-i,-1):
        print(c, end=" ")
        c=c+1
    print('')
Enter number:4
1 2 3 4 
2 3 4 
34 
3 4 
2 3 4 
1 2 3 4 
In [0]:

Find the length of a string without using len functions

In [0]:

In [6]:
str = input("Enter a string: ")
counter = 0
for s in str:
      counter = counter+1
print("Length of the input string is:", counter)
Enter a string: python
Length of the input string is: 6
Find the no of words and characters in a string

In [0]:

In [7]:
string=input("Enter string:")
char=0
word=1
for i in string:
      char=char+1
      if(i==' '):
            word=word+1
print("Number of words in the string:")
print(word)
print("Number of characters in the string:")
print(char)
Enter string:python20
Number of words in the string:
1
Number of characters in the string:
8
In [0]:

Find the no of occurrences of a word in a string

In [8]:
string = "My College name is Alva's Institute of Engineering and technology"
substring = "is"

count = string.count(substring)

# print count
print("The count is:", count)
The count is: 1
# Out:
#   File "<ipython-input-3-55597d20c982>", line 2
#     Open In Colab
#           ^
# SyntaxError: invalid syntax

# %%
n=int(input("Enter number:"))
fact=1

while(n>0):
    fact=fact*n
    n=n-1
print("Factorial of the number is: ")
print(fact)
Enter number:3
Factorial of the number is: 
6
Python Program to reverse a number using loop

In [2]:
r=0
n=int(input("Enter a number: "))
while(n>0):
    dig=n%10
    r=r*10+dig
    n=n//10
print("The reversed no  is:")
print(r)
Enter a number: 131
The reversed no  is:
131n=5;
for i in range(n):
    for j in range(i):
        print ('* ', end="")
    print('')

for i in range(n,0,-1):
    for j in range(i):
        print('* ', end="")
    print('')
* 
* * 
* * * 
* * * * 
* * * * * 
* * * * 
* * * 
* * 
* 
In [0]:

Python Program to replace all occurrences of ‘a’ with ‘$’ in a string.
In [0]:

In [5]:
string=input("Enter string:")
string=string.replace('a','$')
string=string.replace('A','$')
print("Modified string:")
print(string)
Enter string:pavana
Modified string:
p$v$n$
In [0]:

Python Program to remove the nth index characdef remove(string, n):  
      first = string[:n]   
      last = string[n+1:]  
      return first + last
string=input("Enter the sring:")
n=int(input("Enter the index of the character to remove:"))
print("Modified string:")
print(remove(string, n))
Enter the sring:pavana
Enter the index of the character to remove:4
Modified string:
pavaas1=input("Enter first string:")
s2=input("Enter second string:")
if(sorted(s1)==sorted(s2)):
      print("The strings are anagrams.")
else:
      print("The strings aren't anagrams.")
Enter first string:abcd
Enter second string:dabc
The strings are anagrams.
Python Program to form a string where the first character and the last character have been exchanged.

In [8]:
def change(string):
      return string[-1:] + string[1:-1] + string[:1]
string=input("Enter string:")
print("Modified string:")
print(change(string))
Enter string:alvas
Modified string:
slvaa
Python Program to count number of vowels from a non-empty string.

In [9]:
string=input("Enter string:")
vowels=0
for i in string:
      if(i=='a' or i=='e' or i=='i' or i=='o' or i=='u' or i=='A' or i=='E' or i=='I' or i=='O' or i=='U'):
            vowels=vowels+1
print("Number of vowels are:")
print(vowels)
Enter string:alvas
Number of vowels are:
2
Program for Divide by zero error detection

In [0]:

In [10]:
flag = True

def div(a, b):  
       try:
            print("Finally the division of %d/%d is %f" % (a, b,a/b))
            global flag
            flag=False
       except ZeroDivisionError:
            print("Zero Division Error detected")
       else:
            print("Division is successful") 
       finally:
            if flag is True: print("Try again")     
            else:
               print("Thank you")
       
#global flag

while flag is True:
    div(int(input("Enter numerator")),int(input("Enter denominator")))
Enter numerator6
Enter denominator0
Zero Division Error detected
Try again
Enter numerator7
Enter denominator0
Zero Division Error detected
Try again
Enter numerator5
Enter denominator6
Finally the division of 5/6 is 0.833333
Division is successful
Thank you
Program for ValueError error detection

In [11]:
while True:
     try:
         x = int(input("Please enter a number: "))
         print(" That was valid number. Thank you")
         break
     except ValueError:
         print("Oops!  That was no valid number.  Try again...")
Please enter a number: 10
 That was valid number. Thank you
# Out:
#   File "<ipython-input-4-1a1f0d039e9d>", line 9
#     Enter number:3
#                ^
# SyntaxError: invalid syntax
